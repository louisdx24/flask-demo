# %%
import pandas as pd

# %%
url='https://data.moenv.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=CSV'

# %%
df=pd.read_csv(url).dropna()
df
# Out:
#    site county  pm25  datacreationdate itemunit
# 0    大城    彰化縣    18  2024-03-07 21:00    μg/m3
# 1   富貴角    新北市    16  2024-03-07 21:00    μg/m3
# 2    麥寮    雲林縣    24  2024-03-07 21:00    μg/m3
# 3    關山    臺東縣    10  2024-03-07 21:00    μg/m3
# 4    馬公    澎湖縣    19  2024-03-07 21:00    μg/m3
# ..  ...    ...   ...               ...      ...
# 73   土城    新北市    21  2024-03-07 21:00    μg/m3
# 74   新店    新北市    15  2024-03-07 21:00    μg/m3
# 75   萬里    新北市    20  2024-03-07 21:00    μg/m3
# 76   汐止    新北市    17  2024-03-07 21:00    μg/m3
# 77   基隆    基隆市    18  2024-03-07 21:00    μg/m3
#
# [78 rows x 5 columns]

# %% [markdown]
# ### 取 columns&values

# %%
columns=df.columns.tolist()
columns
# Out:
# ['site', 'county', 'pm25', 'datacreationdate', 'itemunit']

# %%
values=df.values.tolist()
values
# Out:
# [['大城', '彰化縣', 18, '2024-03-07 21:00', 'μg/m3'],
#  ['富貴角', '新北市', 16, '2024-03-07 21:00', 'μg/m3'],
#  ['麥寮', '雲林縣', 24, '2024-03-07 21:00', 'μg/m3'],
#  ['關山', '臺東縣', 10, '2024-03-07 21:00', 'μg/m3'],
#  ['馬公', '澎湖縣', 19, '2024-03-07 21:00', 'μg/m3'],
#  ['金門', '金門縣', 33, '2024-03-07 21:00', 'μg/m3'],
#  ['馬祖', '連江縣', 49, '2024-03-07 21:00', 'μg/m3'],
#  ['埔里', '南投縣', 21, '2024-03-07 21:00', 'μg/m3'],
#  ['復興', '高雄市', 34, '2024-03-07 21:00', 'μg/m3'],
#  ['永和', '新北市', 19, '2024-03-07 21:00', 'μg/m3'],
#  ['竹山', '南投縣', 20, '2024-03-07 21:00', 'μg/m3'],
#  ['中壢', '桃園市', 22, '2024-03-07 21:00', 'μg/m3'],
#  ['三重', '新北市', 23, '2024-03-07 21:00', 'μg/m3'],
#  ['冬山', '宜蘭縣', 9, '2024-03-07 21:00', 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 5, '2024-03-07 21:00', 'μg/m3'],
#  ['陽明', '臺北市', 8, '2024-03-07 21:00', 'μg/m3'],
#  ['花蓮', '花蓮縣', 13, '2024-03-07 21:00', 'μg/m3'],
#  ['臺東', '臺東縣', 0, '2024-03-07 21:00', 'μg/m3'],
#  ['恆春', '屏東縣', 1, '2024-03-07 21:00', 'μg/m3'],
#  ['潮州', '屏東縣', 37, '2024-03-07 21:00', 'μg/m3'],
#  ['屏東', '屏東縣', 30, '2024-03-07 21:00', 'μg/m3'],
#  ['小港', '高雄市', 37, '2024-03-07 21:00', 'μg/m3'],
#  ['前鎮', '高雄市', 38, '2024-03-07 21:00', 'μg/m3'],
#  ['前金', '高雄市', 33, '2024-03-07 21:00', 'μg/m3'],
#  ['左營', '高雄市', 38, '2024-03-07 21:00', 'μg/m3'],
#  ['楠梓', '高雄市', 36, '2024-03-07 21:00', 'μg/m3'],
#  ['林園', '高雄市', 33, '2024-03-07 21:00', 'μg/m3'],
#  ['大寮', '高雄市', 38, '2024-03-07 21:00', 'μg/m3'],
#  ['鳳山', '高雄市', 41, '2024-03-07 21:00', 'μg/m3'],
#  ['仁武', '高雄市', 45, '2024-03-07 21:00', 'μg/m3'],
#  ['橋頭', '高雄市', 39, '2024-03-07 21:00', 'μg/m3'],
#  ['美濃', '高雄市', 24, '2024-03-07 21:00', 'μg/m3'],
#  ['臺南', '臺南市', 29, '2024-03-07 21:00', 'μg/m3'],
#  ['安南', '臺南市', 29, '2024-03-07 21:00', 'μg/m3'],
#  ['善化', '臺南市', 30, '2024-03-07 21:00', 'μg/m3'],
#  ['新營', '臺南市', 23, '2024-03-07 21:00', 'μg/m3'],
#  ['嘉義', '嘉義市', 28, '2024-03-07 21:00', 'μg/m3'],
#  ['臺西', '雲林縣', 21, '2024-03-07 21:00', 'μg/m3'],
#  ['朴子', '嘉義縣', 24, '2024-03-07 21:00', 'μg/m3'],
#  ['新港', '嘉義縣', 21, '2024-03-07 21:00', 'μg/m3'],
#  ['崙背', '雲林縣', 19, '2024-03-07 21:00', 'μg/m3'],
#  ['斗六', '雲林縣', 25, '2024-03-07 21:00', 'μg/m3'],
#  ['南投', '南投縣', 25, '2024-03-07 21:00', 'μg/m3'],
#  ['二林', '彰化縣', 25, '2024-03-07 21:00', 'μg/m3'],
#  ['線西', '彰化縣', 23, '2024-03-07 21:00', 'μg/m3'],
#  ['彰化', '彰化縣', 13, '2024-03-07 21:00', 'μg/m3'],
#  ['西屯', '臺中市', 20, '2024-03-07 21:00', 'μg/m3'],
#  ['忠明', '臺中市', 13, '2024-03-07 21:00', 'μg/m3'],
#  ['大里', '臺中市', 12, '2024-03-07 21:00', 'μg/m3'],
#  ['沙鹿', '臺中市', 12, '2024-03-07 21:00', 'μg/m3'],
#  ['豐原', '臺中市', 13, '2024-03-07 21:00', 'μg/m3'],
#  ['三義', '苗栗縣', 16, '2024-03-07 21:00', 'μg/m3'],
#  ['苗栗', '苗栗縣', 22, '2024-03-07 21:00', 'μg/m3'],
#  ['頭份', '苗栗縣', 22, '2024-03-07 21:00', 'μg/m3'],
#  ['新竹', '新竹市', 17, '2024-03-07 21:00', 'μg/m3'],
#  ['竹東', '新竹縣', 14, '2024-03-07 21:00', 'μg/m3'],
#  ['湖口', '新竹縣', 17, '2024-03-07 21:00', 'μg/m3'],
#  ['龍潭', '桃園市', 15, '2024-03-07 21:00', 'μg/m3'],
#  ['平鎮', '桃園市', 10, '2024-03-07 21:00', 'μg/m3'],
#  ['觀音', '桃園市', 18, '2024-03-07 21:00', 'μg/m3'],
#  ['大園', '桃園市', 17, '2024-03-07 21:00', 'μg/m3'],
#  ['桃園', '桃園市', 20, '2024-03-07 21:00', 'μg/m3'],
#  ['大同', '臺北市', 28, '2024-03-07 21:00', 'μg/m3'],
#  ['松山', '臺北市', 25, '2024-03-07 21:00', 'μg/m3'],
#  ['古亭', '臺北市', 20, '2024-03-07 21:00', 'μg/m3'],
#  ['萬華', '臺北市', 20, '2024-03-07 21:00', 'μg/m3'],
#  ['中山', '臺北市', 19, '2024-03-07 21:00', 'μg/m3'],
#  ['士林', '臺北市', 15, '2024-03-07 21:00', 'μg/m3'],
#  ['淡水', '新北市', 19, '2024-03-07 21:00', 'μg/m3'],
#  ['林口', '新北市', 18, '2024-03-07 21:00', 'μg/m3'],
#  ['菜寮', '新北市', 19, '2024-03-07 21:00', 'μg/m3'],
#  ['新莊', '新北市', 19, '2024-03-07 21:00', 'μg/m3'],
#  ['板橋', '新北市', 15, '2024-03-07 21:00', 'μg/m3'],
#  ['土城', '新北市', 21, '2024-03-07 21:00', 'μg/m3'],
#  ['新店', '新北市', 15, '2024-03-07 21:00', 'μg/m3'],
#  ['萬里', '新北市', 20, '2024-03-07 21:00', 'μg/m3'],
#  ['汐止', '新北市', 17, '2024-03-07 21:00', 'μg/m3'],
#  ['基隆', '基隆市', 18, '2024-03-07 21:00', 'μg/m3']]
