# %%
import pandas as pd

# %%
url='https://data.moenv.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=CSV'

# %%
df=pd.read_csv(url).dropna()
df
# Out:
#    site county  pm25  datacreationdate itemunit
# 0    大城    彰化縣  19.0  2024-03-18 07:00    μg/m3
# 1   富貴角    新北市  39.0  2024-03-18 07:00    μg/m3
# 2    麥寮    雲林縣  18.0  2024-03-18 07:00    μg/m3
# 3    關山    臺東縣   6.0  2024-03-18 07:00    μg/m3
# 4    馬公    澎湖縣  15.0  2024-03-18 07:00    μg/m3
# ..  ...    ...   ...               ...      ...
# 73   土城    新北市  15.0  2024-03-18 07:00    μg/m3
# 74   新店    新北市  10.0  2024-03-18 07:00    μg/m3
# 75   萬里    新北市  23.0  2024-03-18 07:00    μg/m3
# 76   汐止    新北市  14.0  2024-03-18 07:00    μg/m3
# 77   基隆    基隆市   6.0  2024-03-18 07:00    μg/m3
#
# [77 rows x 5 columns]

# %% [markdown]
# ### 取 columns&values

# %%
columns=df.columns.tolist()
columns
# Out:
# ['site', 'county', 'pm25', 'datacreationdate', 'itemunit']

# %%
values=df.values.tolist()
values
# Out:
# [['大城', '彰化縣', 19.0, '2024-03-18 07:00', 'μg/m3'],
#  ['富貴角', '新北市', 39.0, '2024-03-18 07:00', 'μg/m3'],
#  ['麥寮', '雲林縣', 18.0, '2024-03-18 07:00', 'μg/m3'],
#  ['關山', '臺東縣', 6.0, '2024-03-18 07:00', 'μg/m3'],
#  ['馬公', '澎湖縣', 15.0, '2024-03-18 07:00', 'μg/m3'],
#  ['馬祖', '連江縣', 28.0, '2024-03-18 07:00', 'μg/m3'],
#  ['埔里', '南投縣', 27.0, '2024-03-18 07:00', 'μg/m3'],
#  ['復興', '高雄市', 49.0, '2024-03-18 07:00', 'μg/m3'],
#  ['永和', '新北市', 12.0, '2024-03-18 07:00', 'μg/m3'],
#  ['竹山', '南投縣', 61.0, '2024-03-18 07:00', 'μg/m3'],
#  ['中壢', '桃園市', 15.0, '2024-03-18 07:00', 'μg/m3'],
#  ['三重', '新北市', 8.0, '2024-03-18 07:00', 'μg/m3'],
#  ['冬山', '宜蘭縣', 15.0, '2024-03-18 07:00', 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 9.0, '2024-03-18 07:00', 'μg/m3'],
#  ['陽明', '臺北市', 6.0, '2024-03-18 07:00', 'μg/m3'],
#  ['花蓮', '花蓮縣', 10.0, '2024-03-18 07:00', 'μg/m3'],
#  ['臺東', '臺東縣', 7.0, '2024-03-18 07:00', 'μg/m3'],
#  ['恆春', '屏東縣', 7.0, '2024-03-18 07:00', 'μg/m3'],
#  ['潮州', '屏東縣', 36.0, '2024-03-18 07:00', 'μg/m3'],
#  ['屏東', '屏東縣', 47.0, '2024-03-18 07:00', 'μg/m3'],
#  ['小港', '高雄市', 42.0, '2024-03-18 07:00', 'μg/m3'],
#  ['前鎮', '高雄市', 40.0, '2024-03-18 07:00', 'μg/m3'],
#  ['前金', '高雄市', 43.0, '2024-03-18 07:00', 'μg/m3'],
#  ['左營', '高雄市', 43.0, '2024-03-18 07:00', 'μg/m3'],
#  ['楠梓', '高雄市', 44.0, '2024-03-18 07:00', 'μg/m3'],
#  ['林園', '高雄市', 50.0, '2024-03-18 07:00', 'μg/m3'],
#  ['大寮', '高雄市', 53.0, '2024-03-18 07:00', 'μg/m3'],
#  ['鳳山', '高雄市', 39.0, '2024-03-18 07:00', 'μg/m3'],
#  ['仁武', '高雄市', 43.0, '2024-03-18 07:00', 'μg/m3'],
#  ['橋頭', '高雄市', 40.0, '2024-03-18 07:00', 'μg/m3'],
#  ['美濃', '高雄市', 27.0, '2024-03-18 07:00', 'μg/m3'],
#  ['臺南', '臺南市', 36.0, '2024-03-18 07:00', 'μg/m3'],
#  ['安南', '臺南市', 37.0, '2024-03-18 07:00', 'μg/m3'],
#  ['善化', '臺南市', 38.0, '2024-03-18 07:00', 'μg/m3'],
#  ['新營', '臺南市', 52.0, '2024-03-18 07:00', 'μg/m3'],
#  ['嘉義', '嘉義市', 70.0, '2024-03-18 07:00', 'μg/m3'],
#  ['臺西', '雲林縣', 15.0, '2024-03-18 07:00', 'μg/m3'],
#  ['朴子', '嘉義縣', 48.0, '2024-03-18 07:00', 'μg/m3'],
#  ['新港', '嘉義縣', 48.0, '2024-03-18 07:00', 'μg/m3'],
#  ['崙背', '雲林縣', 27.0, '2024-03-18 07:00', 'μg/m3'],
#  ['斗六', '雲林縣', 60.0, '2024-03-18 07:00', 'μg/m3'],
#  ['南投', '南投縣', 48.0, '2024-03-18 07:00', 'μg/m3'],
#  ['二林', '彰化縣', 31.0, '2024-03-18 07:00', 'μg/m3'],
#  ['線西', '彰化縣', 19.0, '2024-03-18 07:00', 'μg/m3'],
#  ['彰化', '彰化縣', 16.0, '2024-03-18 07:00', 'μg/m3'],
#  ['西屯', '臺中市', 21.0, '2024-03-18 07:00', 'μg/m3'],
#  ['忠明', '臺中市', 18.0, '2024-03-18 07:00', 'μg/m3'],
#  ['大里', '臺中市', 26.0, '2024-03-18 07:00', 'μg/m3'],
#  ['沙鹿', '臺中市', 18.0, '2024-03-18 07:00', 'μg/m3'],
#  ['豐原', '臺中市', 15.0, '2024-03-18 07:00', 'μg/m3'],
#  ['三義', '苗栗縣', 17.0, '2024-03-18 07:00', 'μg/m3'],
#  ['苗栗', '苗栗縣', 13.0, '2024-03-18 07:00', 'μg/m3'],
#  ['頭份', '苗栗縣', 15.0, '2024-03-18 07:00', 'μg/m3'],
#  ['新竹', '新竹市', 14.0, '2024-03-18 07:00', 'μg/m3'],
#  ['竹東', '新竹縣', 13.0, '2024-03-18 07:00', 'μg/m3'],
#  ['湖口', '新竹縣', 13.0, '2024-03-18 07:00', 'μg/m3'],
#  ['龍潭', '桃園市', 9.0, '2024-03-18 07:00', 'μg/m3'],
#  ['平鎮', '桃園市', 13.0, '2024-03-18 07:00', 'μg/m3'],
#  ['觀音', '桃園市', 28.0, '2024-03-18 07:00', 'μg/m3'],
#  ['大園', '桃園市', 22.0, '2024-03-18 07:00', 'μg/m3'],
#  ['桃園', '桃園市', 7.0, '2024-03-18 07:00', 'μg/m3'],
#  ['大同', '臺北市', 13.0, '2024-03-18 07:00', 'μg/m3'],
#  ['松山', '臺北市', 17.0, '2024-03-18 07:00', 'μg/m3'],
#  ['古亭', '臺北市', 13.0, '2024-03-18 07:00', 'μg/m3'],
#  ['萬華', '臺北市', 10.0, '2024-03-18 07:00', 'μg/m3'],
#  ['中山', '臺北市', 8.0, '2024-03-18 07:00', 'μg/m3'],
#  ['士林', '臺北市', 5.0, '2024-03-18 07:00', 'μg/m3'],
#  ['淡水', '新北市', 14.0, '2024-03-18 07:00', 'μg/m3'],
#  ['林口', '新北市', 12.0, '2024-03-18 07:00', 'μg/m3'],
#  ['菜寮', '新北市', 14.0, '2024-03-18 07:00', 'μg/m3'],
#  ['新莊', '新北市', 7.0, '2024-03-18 07:00', 'μg/m3'],
#  ['板橋', '新北市', 9.0, '2024-03-18 07:00', 'μg/m3'],
#  ['土城', '新北市', 15.0, '2024-03-18 07:00', 'μg/m3'],
#  ['新店', '新北市', 10.0, '2024-03-18 07:00', 'μg/m3'],
#  ['萬里', '新北市', 23.0, '2024-03-18 07:00', 'μg/m3'],
#  ['汐止', '新北市', 14.0, '2024-03-18 07:00', 'μg/m3'],
#  ['基隆', '基隆市', 6.0, '2024-03-18 07:00', 'μg/m3']]

# %%
set(df['county'])
# Out:
# {'南投縣',
#  '嘉義市',
#  '嘉義縣',
#  '基隆市',
#  '宜蘭縣',
#  '屏東縣',
#  '彰化縣',
#  '新北市',
#  '新竹市',
#  '新竹縣',
#  '桃園市',
#  '澎湖縣',
#  '臺中市',
#  '臺北市',
#  '臺南市',
#  '臺東縣',
#  '花蓮縣',
#  '苗栗縣',
#  '連江縣',
#  '雲林縣',
#  '高雄市'}

# %%
six_countys=["臺北市","新北市","桃園市","臺中市","臺南市","高雄市"]

# %%
df.groupby("county").get_group("臺北市")["pm25"].mean()
# Out:
# 10.285714285714286

# %%
for county in six_countys:
    pm25=round(df.groupby("county").get_group(county)["pm25"].mean(),2)
    print(county,pm25)
# Out:
# 臺北市 10.29
# 新北市 14.75
# 桃園市 15.67
# 臺中市 19.6
# 臺南市 40.75
# 高雄市 42.75
